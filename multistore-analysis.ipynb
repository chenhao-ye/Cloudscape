# %%
from cloudscape import load_studies, extract_svc_info
import csv

# %%
architectures = load_studies("./data/graphs/")
print(f"There are {len(architectures)} architectures in the dataset.")
architectures = [a for a in architectures if a.use_for_analysis()]
print(f"We will analyze {len(architectures)} of them.")
# Out:
# There are 396 architectures in the dataset.
# We will analyze 340 of them.

# %%
svc_info = extract_svc_info("./data/services.csv")

# %%
print(svc_info)
# Out:
# {'Transcribe': {'name': 'Transcribe', 'capability': 'compute', 'image_url': 'transcribe', 'is_aws': True, 'schema': '', 'aws_product_categories': 'ML'}, 'LookoutForVision': {'name': 'LookoutForVision', 'capability': 'compute', 'image_url': 'lookoutforvision', 'is_aws': True, 'schema': '', 'aws_product_categories': 'ML'}, 'PrivateLink': {'name': 'PrivateLink', 'capability': 'networking', 'image_url': 'privatelink', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Networking and Content Delivery'}, 'SystemsManager': {'name': 'SystemsManager', 'capability': 'control', 'image_url': 'systemsmanager', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Management and Governance'}, 'UserCompanyDeveloper': {'name': 'UserCompanyDeveloper', 'capability': 'User', 'image_url': 'usercompanydeveloper', 'is_aws': False, 'schema': '', 'aws_product_categories': ''}, 'LakeFormation': {'name': 'LakeFormation', 'capability': 'control', 'image_url': 'lakeformation', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Analytics'}, 'UserConsumerWebMobile': {'name': 'UserConsumerWebMobile', 'capability': 'User', 'image_url': 'userconsumerwebmobile', 'is_aws': False, 'schema': '', 'aws_product_categories': ''}, 'AppStream': {'name': 'AppStream', 'capability': 'other', 'image_url': 'appstream', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Enduser Computing'}, 'MSK': {'name': 'MSK', 'capability': 'integration', 'image_url': 'msk', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Analytics'}, 'VPN': {'name': 'VPN', 'capability': 'networking', 'image_url': 'vpn', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Networking and Content Delivery'}, 'Translate': {'name': 'Translate', 'capability': 'compute', 'image_url': 'translate', 'is_aws': True, 'schema': '', 'aws_product_categories': 'ML'}, 'MediaPackage': {'name': 'MediaPackage', 'capability': 'compute', 'image_url': 'mediapackage', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Media Services'}, 'CodePipeline': {'name': 'CodePipeline', 'capability': 'other', 'image_url': 'codepipeline', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Developer Tools'}, 'Organizations': {'name': 'Organizations', 'capability': 'other', 'image_url': 'organizations', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Management and Governance'}, 'Firehose': {'name': 'Firehose', 'capability': 'integration', 'image_url': 'firehose', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Analytics'}, 'Athena': {'name': 'Athena', 'capability': 'compute', 'image_url': 'athena', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Analytics'}, 'UserCompanyElementalLiveDevice': {'name': 'UserCompanyElementalLiveDevice', 'capability': 'User', 'image_url': 'usercompanyelementallivedevice', 'is_aws': False, 'schema': '', 'aws_product_categories': ''}, 'DynamoDBStream': {'name': 'DynamoDBStream', 'capability': 'integration', 'image_url': 'dynamodbstream', 'is_aws': True, 'schema': '', 'aws_product_categories': ''}, 'Kinesis': {'name': 'Kinesis', 'capability': 'integration', 'image_url': 'kinesis', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Analytics'}, 'UserConsumerAlexaGoogleHome': {'name': 'UserConsumerAlexaGoogleHome', 'capability': 'User', 'image_url': 'userconsumeralexagooglehome', 'is_aws': False, 'schema': '', 'aws_product_categories': ''}, 'STS': {'name': 'STS', 'capability': 'control', 'image_url': 'sts', 'is_aws': True, 'schema': '', 'aws_product_categories': ''}, 'Lex': {'name': 'Lex', 'capability': 'other', 'image_url': 'lex', 'is_aws': True, 'schema': '', 'aws_product_categories': 'ML'}, 'GlobalAccelerator': {'name': 'GlobalAccelerator', 'capability': 'networking', 'image_url': 'globalaccelerator', 'is_aws': True, 'schema': '', 'aws_product_categories': 'Networking and Content Delivery'}, 'CloudWatch': {'name': 'CloudWatch', 'capability': 'control', 'image_url': 'cloudwatch', 'is_aws': True, 'schema': '', 'aws_product_categories':  ...

# %%
def cleanup_url(s) -> str:
    return s.split("&list=")[0]

# %%
with open("cloudscape.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["name", "link", "num_nodes", "num_edges", "services", "goals"])
    for arch in architectures:
        g = arch.nx_graph
        g_dict = g.graph
        services = set(arch.get_all_nodes_services())
        goals = set(arch.get_functional_goals())
        writer.writerow(
            [
                g_dict["name"],
                cleanup_url(g_dict["link"]),
                g.number_of_nodes(),
                g.number_of_edges(),
                ",".join(services),
                ",".join(goals),
            ]
        )

# %%
def is_store_type(svc):
    return (svc_info[svc]["capability"] == "storage" and svc != "EBS") or (svc in {"OpenSearch", "MSK", "QuickSight"}) or ("Kinesis" in svc)

def get_storage_types(arch):
    return {svc for svc in arch.get_all_nodes_services() if is_store_type(svc)}

# %%
with open("multistore.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["name", "link", "stores"])
    for arch in architectures:
        stores = get_storage_types(arch)
        if len(stores) >= 3:
            g_dict = arch.nx_graph.graph
            writer.writerow([g_dict["name"], cleanup_url(g_dict["link"]), ",".join(stores)])
